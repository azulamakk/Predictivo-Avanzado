# %% [markdown]
# # SISTEMAS DE RECOMENDACIÓN 2
# ## PRÁCTICA

# %% [markdown]
# <img src="portada.jpg" align="center" width="80%"/>

# %% [markdown]
# El principal objetivo de cualquier sistema de recomendación es ofrecer a los usuarios una experiencia personalizada. ¿Cómo traducimos esto a un problema de machine learning? Tenemos dos tipos de problemas:
#
# - Problema de predicción: el primer enfoque es aquel en el que nos gustaría predecir el valor de calificación de una combinación usuario-artículo con la suposición de que se dispone de datos de entrenamiento que indican la preferencia de un usuario por otros artículos. Imaginemos una matriz m × n, donde m es el número de usuarios y n el número de elementos, y el objetivo es predecir los valores que faltan (o no observados). En otras palabras, **queremos predecir el rating que un usuario preexistente le pondría a un ítem que aún no consumió.**
# <br>
#
# - Problema de clasificación: en otras ocasiones, deseamos **recomendar los k mejores artículos para un usuario concreto o determinar los k mejores usuarios a los que dirigirnos para un ítem específico**. Este problema también se denomina problema de recomendación top-k y es la formulación de clasificación del problema de recomendación. Pensemos en un motor de búsqueda en el que, en función de quién realice la búsqueda, nos gustaría mostrar los elementos top-k para ofrecer resultados personalizados basados en sus preferencias anteriores y en su actividad reciente.

# %% [markdown]
# Clasficación de sistemas de recomendación
#
# <img src="sintesis.jpg" align="center" width="60%"/>

# %%
# !pip install chart_studio
# !pip install datapane
# !pip install pip install scikit-surprise
# !pip install --upgrade pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datapane as dp
import chart_studio.plotly as py
import chart_studio
import os

from sklearn.model_selection import train_test_split as skl_train_test_split
from surprise import KNNBasic,NormalPredictor,BaselineOnly,NMF

# username = os.environ['PLOTLY_USERNAME']
# api_key = os.environ['PLOTLY_API_KEY']
# chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
# %matplotlib inline

# %% [markdown]
# ## Ejemplo práctico de un SR basado en contenido

# %% [markdown]
# Utilizamos el dataset goodbooks-10k (disponible en Kaggle). El primer CSV contiene datos de 10k libros puntuados por 53k usuarios. El segundo CSV contiene los metadatos (título, autor, ISBN, etc) para cada uno de los 10k libros.

# %%
ratings_data = pd.read_csv('./data/books/ratings.csv.zip')
books_metadata = pd.read_csv('./data/books/books.csv.zip')
ratings_data.head(10)
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4
# 5        1     2077       4
# 6        1     2487       4
# 7        1     2900       5
# 8        1     3662       4
# 9        1     3922       5

# %%
ratings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981756 entries, 0 to 981755
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   book_id  981756 non-null  int64
#  1   user_id  981756 non-null  int64
#  2   rating   981756 non-null  int64
# dtypes: int64(3)
# memory usage: 22.5 MB

# %%
books_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         10000 non-null  int64
#  1   book_id                    10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
#  13  ratings_count              10000 non-null  int64
#  14  work_ratings_count         10000 non-null  int64
#  15  work_text_reviews_count    10000 non-null  int64
#  16  ratings_1                  10000 non-null  int64
#  17  ratings_2                  10000 non-null  int64
#  18  ratings_3                  10000 non-null  int64
#  19  ratings_4                  10000 non-null  int64
#  20  ratings_5                  10000 non-null  int64
#  21  image_url                  10000 non-null  object
#  22  small_image_url            10000 non-null  object
# dtypes: float64(3), int64(13), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# Tenemos además un dataset de tags, que nos da detalles sobre el argumento del libro.

# %%
book_tags = pd.read_csv('./data/books/book_tags.csv')
tags = pd.read_csv('./data/books/tags.csv')

# %%
data = pd.merge(book_tags, tags, left_on='tag_id', right_on='tag_id', how='inner')
titles = books_metadata[['id', 'book_id','title','authors']]
data = pd.merge(titles, data, left_on='book_id', right_on='goodreads_book_id')
data.drop(['goodreads_book_id', 'tag_id', 'count'], axis=1,inplace=True)
data.head(3)
# Out:
#    id  book_id                                    title          authors  \
# 0   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 2   1  2767052  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
#
#     tag_name
# 0    to-read
# 1    fantasy
# 2  favorites

# %%
list_tags = data.groupby(by='book_id')['tag_name'].apply(set).apply(list)
books_metadata['tags'] = books_metadata['book_id'].apply(lambda x: ' '.join(list_tags[x]))
pd.reset_option('max_colwidth')
books_metadata.head(3)
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
#
#                              original_title  ... work_ratings_count  \
# 0                          The Hunger Games  ...            4942365
# 1  Harry Potter and the Philosopher's Stone  ...            4800065
# 2                                  Twilight  ...            3916824
#
#   work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 0                  155254      66715     127936     560092    1481305
# 1                   75867      75504     101676     455024    1156318
# 2                   95009     456191     436802     793319     875073
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
#
#                                                 tags
# 0  my-books read-2012 coming-of-age borrowed my-l...
# 1  my-books owned-books my-library i-own classics...
# 2  my-books read-in-2008 never-again owned-books ...
#
# [3 rows x 24 columns]

# %%
books_metadata['tags'][0]
# Out:
# 'my-books read-2012 coming-of-age borrowed my-library i-own read-in-2012 read-more-than-once ebooks audio read-2011 action thriller series reviewed sci-fi-fantasy favorite favorite-books read-in-2013 distopian owned adventure default fantasy favorites hunger-games trilogy science-fiction suspense action-adventure audiobook sf ya-fantasy teen-fiction favourite-books favorite-series shelfari-favorites 5-stars teen ebook favs fantasy-sci-fi favourites dystopian-fiction faves books-i-own sci-fi finished read-in-2014 young-adult dystopia love the-hunger-games fiction reread distopia my-favorites post-apocalyptic future love-triangle suzanne-collins all-time-favorites dystopias novels books contemporary finished-series to-buy completed-series scifi drama english read-in-2011 young-adult-fiction scifi-fantasy currently-reading survival ya-dystopian ya-lit library novel favourite 2012-reads e-book read-in-2010 to-read dystopian ya-books ya-fiction futuristic book-club ya loved audiobooks 5-star re-read own-it speculative-fiction kindle romance'

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# Al trabajar con texto, podemos aplicar una transformación llamada **TF-IDF**, o Term Frequency-Inverse Document Frecuency.
#
# El **número de features** que crea es igual al número total de palabras distintas utilizadas en la columna de tags.
#
# Los **valores** son directamente *proporcionales al número de veces que se utiliza una palabra concreta* e *inversamente proporcionales al número de documentos (películas en este caso) en los que se utiliza la palabra*.
#
# Penalizará una palabra presente en los tags de un libro si es común a muchos libros. Las palabras que aparecen varias veces pero son comunes a muchos libros no son tan útiles para diferenciar los distintos libros.
#
# En otras palabras, **el proceso TF-IDF nos dice que tan relevante es una palabra a un documento, en una colección de documentos**.

# %% [markdown]
# ### Cálculo
#
# t - término (palabra) <br>
# d - documento (conjunto de palabras) <br>
# N - cantidad de documentos
# <br>
#
# tf(t,d) = cantidad de t in d / cantidad de palabras en d
#
# df(t) = ocurrencia de t en N documentos
#
# idf(t) = N/df
#
# IDF es la inversa de la frecuencia de documentos que mide que tan informativo es el término t. Cuando calculamos IDF, será muy bajo para las palabras más frecuentes, como las stop words (porque están presentes en casi todos los documentos, y N/df dará un valor muy bajo a esa palabra). Esto da finalmente lo que queremos, un peso relativo.
#
# Se suele usar el logaritmo para contrarrestar el efecto de un N muy grande: idf(t) = log(N/(df + 1)).
#
# El score final será la multiplicación de ambos términos:
#
# **tf-idf(t, d) = tf(t, d) * log(N/(df + 1))**

# %%
tfidf = TfidfVectorizer(stop_words='english')

tags_matrix = tfidf.fit_transform(books_metadata['tags'])

tags_matrix.shape
# Out:
# (10000, 16396)

# %%
tags_matrix
# Out:
# <10000x16396 sparse matrix of type '<class 'numpy.float64'>'
# 	with 767020 stored elements in Compressed Sparse Row format>

# %%
#Cantidad de veces que se repite cada término
tfidf.vocabulary_
# Out:
# {'books': 2075,
#  'read': 11635,
#  '2012': 253,
#  'coming': 3228,
#  'age': 686,
#  'borrowed': 2112,
#  'library': 8325,
#  'ebooks': 4490,
#  'audio': 1333,
#  '2011': 251,
#  'action': 563,
#  'thriller': 14012,
#  'series': 12640,
#  'reviewed': 11939,
#  'sci': 12468,
#  'fi': 5268,
#  'fantasy': 5132,
#  'favorite': 5188,
#  '2013': 254,
#  'distopian': 4180,
#  'owned': 10424,
#  'adventure': 641,
#  'default': 3899,
#  'favorites': 5190,
#  'hunger': 6863,
#  'games': 5744,
#  'trilogy': 14289,
#  'science': 12470,
#  'fiction': 5289,
#  'suspense': 13612,
#  'audiobook': 1334,
#  'sf': 12671,
#  'ya': 15260,
#  'teen': 13848,
#  'favourite': 5196,
#  'shelfari': 12754,
#  'stars': 13324,
#  'ebook': 4487,
#  'favs': 5199,
#  'favourites': 5197,
#  'dystopian': 4451,
#  'faves': 5182,
#  'finished': 5358,
#  '2014': 255,
#  'young': 15308,
#  'adult': 632,
#  'dystopia': 4450,
#  'love': 8570,
#  'reread': 11889,
#  'distopia': 4179,
#  'post': 11099,
#  'apocalyptic': 1068,
#  'future': 5686,
#  'triangle': 14275,
#  'suzanne': 13620,
#  'collins': 3179,
#  'time': 14053,
#  'dystopias': 4453,
#  'novels': 10119,
#  'contemporary': 3375,
#  'buy': 2418,
#  'completed': 3269,
#  'scifi': 12480,
#  'drama': 4328,
#  'english': 4736,
#  'currently': 3705,
#  'reading': 11658,
#  'survival': 13600,
#  'lit': 8426,
#  'novel': 10105,
#  'reads': 11662,
#  'book': 2049,
#  '2010': 249,
#  'futuristic': 5688,
#  'club': 3089,
#  'loved': 8573,
#  'audiobooks': 1336,
#  'star': 13315,
#  'speculative': 13198,
#  'kindle': 7818,
#  'romance': 12101,
#  'classics': 3027,
#  '2015': 256,
#  'paranormal': 10526,
#  'jk': 7461,
#  'rowling': 12168,
#  '2016': 257,
#  'british': 2277,
#  'england': 4733,
#  'childrens': 2884,
#  'wizards': 15119,
#  'shelf': 12752,
#  'kids': 7780,
#  'childhood': 2877,
#  'middle': 9272,
#  'grade': 6068,
#  'urban': 14547,
#  'magic': 8724,
#  'rereads': 11892,
#  'bookshelf': 2082,
#  'children': 2883,
#  'classic': 3020,
#  'juvenile': 7594,
#  '2017': 259,
#  'witches': 15109,
#  'mystery': 9709,
#  'harry': 6375,
#  'potter': 11121,
#  'youth': 15314,
#  'friendship': 5633,
#  'supernatural': 13575,
#  'literature': 8435,
#  '2008': 244,
#  'séries': 13689,
#  'stephanie': 13365,
#  'meyer': 9232,
#  'pnr': 10964,
#  'american': 879,
#  'guilty': 6211,
#  'pleasures': 10950,
#  'horror': 6766,
#  'twilight': 14391,
#  'werewolves': 14964,
#  'movie': 9586,
#  'stephenie': 13369,
#  'chick': 2857,
#  'meh': 9129,
#  'vampire': 14603,
#  'youngadult': 15310,
#  'did': 4087,
#  'finish': 5356,
#  '2009': 246,
#  'adults': 636,
#  'romantic': 12113,
#  'abandoned': 472,
#  'movies': 9588,
#  'dnf': 4213,
#  'pleasure': 10949,
#  'vamps': 14607,
#  'high': 6565,
#  'school': 12458,
#  'saga': 12280,
#  'vampires': 14604,
#  'banned': 1540,
#  '1001': 42,
#  'rory': 12141,
#  'gilmore': 5933,
#  'challenge': 2739,
#  'required': 11887,
#  'crime': 3594,
#  'realistic': 11676,
#  'modern': 9437,
#  'history': 6638,
#  'literary': 8431,
#  'clàssics': 3094,
#  '20th': 274,
#  'century': 2717,
#  'harper': 6366,
#  'lee': 8188,
#  'die': 4092,
#  'wish': 15097,
#  'list': 8418,
#  'pulitzer': 11411,
#  'prize': 11256,
#  'southern': 13165,
#  'race': 11524,
#  'usa': 14559,
#  'historical': 6623,
#  'racism': 11532,
#  'bookclub': 2056,
#  'general': 5828,
#  'family': 5095,
#  'america': 878,
#  'new': 9920,
#  'york': 15302,
#  '1920s': 151,
#  'scott': 12495,
#  'fitzgerald': 5396,
#  'stand': 13305,
#  'cancer': 2503,
#  'emotional': 4675,
#  'sad': 12269,
#  'want': 14849,
#  'tear': 13821,
#  'jerkers': 7427,
#  'fault': 5176,
#  'humor': 6855,
#  'cried': 3593,
#  'jerker': 7426,
#  'signed': 12887,
#  'funny': 5679,
#  'story': 13421,
#  'death': 3860,
#  'illness': 6959,
#  'john': 7487,
#  'green': 6125,
#  'unfinished': 14479,
#  'personal': 10725,
#  'dragons': 4327,
#  'tolkien': 14118,
#  'epic': 4791,
#  'lord': 8542,
#  'rings': 12004,
#  'hold': 6688,
#  'earth': 4469,
#  'audible': 1331,
#  'jrr': 7539,
#  'salinger': 12311,
#  'bildungsroman': 1843,
#  '1950s': 170,
#  '2006': 242,
#  'thrillers': 14015,
#  'religion': 11821,
#  'home': 6714,
#  'robert': 12059,
#  'langdon': 8075,
#  'murder': 9635,
#  'روايات': 15957,
#  'dan': 3768,
#  'brown': 2311,
#  '2005': 241,
#  'popular': 11057,
#  'art': 1181,
#  'italy': 7304,
#  'paperback': 10510,
#  'conspiracy': 3341,
#  'mysteries': 9706,
#  'mistery': 9387,
#  'detective': 4015,
#  'religious': 11825,
#  'nook': 10049,
#  'regency': 11767,
#  'jane': 7351,
#  'austen': 1359,
#  'tbr': 13804,
#  '19th': 214,
#  'women': 15144,
#  'brit': 2273,
#  'culture': 3685,
#  'asia': 1235,
#  'islam': 7276,
#  'cultural': 3683,
#  'war': 14854,
#  'non': 10031,
#  'afghanistan': 668,
#  '21st': 278,
#  'khaled': 7751,
#  'hosseini': 6784,
#  'multicultural': 9614,
#  'group': 6164,
#  'east': 4473,
#  'recommended': 11717,
#  'international': 7185,
#  'contempor': 3368,
#  'ary': 1216,
#  'veronica': 14663,
#  'roth': 12155,
#  'divergent': 4189,
#  'george': 5866,
#  'orwell': 10366,
#  'philosophy': 10791,
#  'satire': 12389,
#  'social': 13070,
#  'commentary': 3236,
#  'political': 11019,
#  'politics': 11021,
#  'ｆａｖｏｒｉｔｅｓ': 16392,
#  'communism': 3248,
#  'novella': 10116,
#  'allegory': 817,
#  'animals': 987,
#  'translated': 14237,
#  'anne': 1000,
#  'frank': 5572,
#  'jewish': 7443,
#  'world': 15178,
#  'ii': 6942,
#  'biography': 1881,
#  'autobiography': 1386,
#  'netherlands': 9898,
#  'diary': 4072,
#  'true': 14316,
#  'memoir': 9155,
#  'bio': 1862,
#  'german': 5877,
#  'biographical': 1877,
#  'inspirational': 7134,
#  'ww2': 15226,
#  'dutch': 4428,
#  'autobiographies': 1385,
#  'holocaust': 6711,
#  'auto': 1379,
#  'diaries': 4071,
#  'biographies': 1880,
#  'memoirs': 9157,
#  'wwii': 15229,
#  'germany': 5880,
#  'nonfiction': 10040,
#  'female': 5228,
#  'authors': 1375,
#  'europe': 4931,
#  'swedish': 13641,
#  'scandinavian': 12420,
#  'translation': 14238,
#  'stieg': 13386,
#  'larsson': 8094,
#  'gave': 5788,
#  'dark': 3800,
#  'couldn': 3483,
#  'sweden': 13640,
#  'didn': 4090,
#  'scandinavia': 12419,
#  'abuse': 527,
#  'millennium': 9314,
#  'travel': 14251,
#  'lotr': 8559,
#  'fantasia': 5122,
#  'fantasía': 5137,
#  'elves': 4654,
#  'boarding': 1996,
#  'hp': 6813,
#  'author': 1374,
#  'multiple': 9618,
#  'times': 14059,
#  '2003': 239,
#  'magical': 8725,
#  'rape': 11591,
#  'ghosts': 5899,
#  'afterlife': 679,
#  'realism': 11674,
#  'alice': 799,
#  'sebold': 12541,
#  'grief': 6143,
#  '2004': 240,
#  'france': 5555,
#  'psychology': 11382,
#  'william': 15051,
#  'shakespeare': 12694,
#  'plays': 10942,
#  'romeo': 12125,
#  'juliet': 7563,
#  'theater': 13944,
#  'poetry': 10985,
#  'theatre': 13946,
#  'stories': 13415,
#  '16th': 101,
#  'play': 10937,
#  'assigned': 1262,
#  'teatro': 13828,
#  'tragedy': 14209,
#  'renaissance': 11844,
#  '9th': 432,
#  'dysfunctional': 4447,
#  'creepy': 3581,
#  'summer': 13556,
#  'psychological': 11378,
#  'recommend': 11714,
#  'mental': 9174,
#  'gone': 6018,
#  'girl': 5938,
#  'fun': 5669,
#  'bought': 2130,
#  'maybe': 9017,
#  'marriage': 8914,
#  'listened': 8422,
#  'gillian': 5930,
#  'flynn': 5453,
#  'purchased': 11427,
#  'sociopath': 13080,
#  'segregation': 12562,
#  '1960s': 176,
#  'mississippi': 9378,
#  'kathryn': 7660,
#  'stockett': 13392,
#  'help': 6488,
#  'civil': 2987,
#  'rights': 11997,
#  'maids': 8748,
#  'racial': 11529,
#  'discrimination': 4156,
#  'african': 674,
#  'steinbeck': 13355,
#  'california': 2468,
#  '1930s': 154,
#  'novellas': 10117,
#  'americana': 880,
#  'nobel': 10017,
#  'historic': 6621,
#  'geisha': 5810,
#  'asian': 1236,
#  'japan': 7362,
#  'japanese': 7363,
#  'erótica': 4850,
#  'chic': 2852,
#  '50': 360,
#  'shades': 12683,
#  'erotica': 4843,
#  'chicklit': 2860,
#  'james': 7344,
#  'alpha': 838,
#  'male': 8779,
#  'steamy': 13348,
#  'sex': 12661,
#  'sexy': 12668,
#  'erotic': 4842,
#  'college': 3176,
#  'nope': 10055,
#  'dropped': 4366,
#  'grey': 6140,
#  'boyfriends': 2165,
#  'virgin': 14741,
#  'heroine': 6524,
#  'bdsm': 1634,
#  'hot': 6790,
#  'wtf': 15219,
#  'males': 8780,
#  'waste': 14881,
#  'billionaire': 1851,
#  'philosophical': 10789,
#  'latin': 8108,
#  'inspiring': 7139,
#  'brazilian': 2217,
#  'self': 12578,
#  'improvement': 7010,
#  'paulo': 10603,
#  'coelho': 3130,
#  'development': 4031,
#  'africa': 673,
#  'motivational': 9566,
#  'inspiration': 7133,
#  'life': 8351,
#  'spirituality': 13232,
#  'alchemist': 767,
#  'spain': 13177,
#  'fable': 5048,
#  'spiritual': 13228,
#  'brazil': 2216,
#  'newberry': 9923,
#  'grades': 6073,
#  'chapter': 2774,
#  'award': 1426,
#  'winners': 15077,
#  'kid': 7766,
#  'need': 9852,
#  'unlimited': 14506,
#  'thought': 14001,
#  'provoking': 11338,
#  'winner': 15076,
#  'alouds': 836,
#  'christian': 2930,
#  'christianity': 2936,
#  'lewis': 8285,
#  'narnia': 9776,
#  'chronicles': 2950,
#  'aloud': 835,
#  'cs': 3666,
#  'chicago': 2854,
#  'audrey': 1340,
#  'niffenegger': 9966,
#  'asoiaf': 1245,
#  'rr': 12178,
#  'martin': 8927,
#  'song': 13110,
#  'ice': 6911,
#  'game': 5743,
#  'thrones': 14019,
#  'medieval': 9112,
#  'elizabeth': 4635,
#  'gilbert': 5926,
#  'india': 7041,
#  'indonesia': 7058,
#  'yoga': 15297,
#  'food': 5473,
#  'writing': 15212,
#  'stopped': 13408,
#  'percy': 10690,
#  'jackson': 7326,
#  'greek': 6123,
#  'olympians': 10261,
#  'mythology': 9719,
#  'gods': 6000,
#  'rick': 11982,
#  'riordan': 12006,
#  'sisters': 12941,
#  'louisa': 8567,
#  'alcott': 776,
#  'uk': 14425,
#  'feminism': 5233,
#  'bronte': 2294,
#  'writers': 15211,
#  'gothic': 6054,
#  'charlotte': 2792,
#  'victorian': 14698,
#  'womens': 15145,
#  'fluff': 5445,
#  'saw': 12403,
#  'notebook': 10087,
#  'sparks': 13184,
#  'seen': 12559,
#  'relationships': 11802,
#  'nicholas': 9950,
#  'man': 8798,
#  'booker': 2061,
#  'canadian': 2496,
#  'canada': 2495,
#  'great': 6117,
#  'depression': 3974,
#  'sara': 12369,
#  'gruen': 6178,
#  'aging': 700,
#  'elephants': 4615,
#  'era': 4817,
#  'selections': 12574,
#  'circus': 2979,
#  'australian': 1367,
#  'favouri': 5194,
#  'tes': 13913,
#  'utopia': 14571,
#  'ray': 11622,
#  'bradbury': 2180,
#  'censorship': 2711,
#  'werewolf': 14962,
#  'shifters': 12788,
#  'shapeshifters': 12719,
#  'childrensbooks': 2886,
#  'nostalgia': 10082,
#  'memories': 9161,
#  'humour': 6859,
#  '100': 38,
#  'lifetime': 8356,
#  'picture': 10841,
#  'readers': 11655,
#  'stuff': 13487,
#  'elementary': 4610,
#  'short': 12825,
#  'comedy': 3213,
#  'shel': 12749,
#  'silverstein': 12901,
#  'illustrated': 6963,
#  'poems': 10974,
#  'child': 2871,
#  'kiddos': 7772,
#  'mortal': 9547,
#  'instruments': 7153,
#  'angels': 964,
#  'demons': 3953,
#  'shadowhunters': 12686,
#  'lgbt': 8294,
#  'faeries': 5064,
#  'cassandra': 2618,
#  'clare': 3008,
#  'inheritance': 7103,
#  'christopher': 2946,
#  'paolini': 10504,
#  'cycle': 3727,
#  'dragon': 4322,
#  'eragon': 4818,
#  'space': 13173,
#  'aliens': 803,
#  '1970s': 182,
#  'hilarious': 6579,
#  'douglas': 4297,
#  'adams': 581,
#  'fantascienza': 5120,
#  'humorous': 6858,
#  'aldous': 777,
#  'huxley': 6884,
#  'breaking': 2223,
#  'dawn': 3833,
#  'sagas': 12283,
#  'hardcover': 6344,
#  'teens': 13853,
#  'pregnancy': 11177,
#  'strong': 13464,
#  'south': 13163,
#  'bees': 1682,
#  'sue': 13533,
#  'monk': 9490,
#  'kidd': 7768,
#  'mark': 8892,
#  'twain': 14380,
#  'slavery': 13000,
#  'ap': 1059,
#  'girls': 5943,
#  'white': 15002,
#  'animal': 985,
#  'newbery': 9924,
#  'honor': 6738,
#  'asperger': 1247,
#  'syndrome': 13677,
#  'narrativa': 9779,
#  'alex': 787,
#  'bookgroup': 2064,
#  'health': 6438,
#  'aspergers': 1248,
#  'autism': 1378,
#  'spectrum': 13197,
#  'misc': 9364,
#  'teaching': 13815,
#  'good': 6021,
#  '8th': 418,
#  '420': 347,
#  'disability': 4133,
#  'special': 13192,
#  'needs': 9854,
#  'selection': 12573,
#  'alcoholism': 774,
#  'unreliable': 14519,
#  'narrator': 9782,
#  'adultery': 633,
#  'paula': 10600,
#  'hawkins': 6414,
#  'philip': 10774,
#  'pullman': 11414,
#  'steampunk': 13346,
#  'materials': 8970,
#  'emily': 4670,
#  'classici': 3023,
#  'jodi': 7476,
#  'picoult': 10838,
#  'dying': 4440,
#  'ethics': 4915,
#  'medical': 9108,
#  'alones': 834,
#  'vonnegut': 14784,
#  'kurt': 8004,
#  'postmodern': 11109,
#  'bbc': 1625,
#  'big': 1831,
#  'georgia': 5869,
#  'margaret': 8865,
#  'mitchell': 9395,
#  'wind': 15066,
#  'favoritos': 5191,
#  'adolescence': 614,
#  'epistolary': 4804,
#  'lgbtqia': 8298,
#  'lgbtq': 8295,
#  'sciencefiction': 12472,
#  'opera': 10303,
#  'hugo': 6836,
#  'ender': 4709,
#  'military': 9306,
#  'orson': 10361,
#  'card': 2550,
#  'romanticism': 12116,
#  'monsters': 9500,
#  'university': 14501,
#  'uni': 14484,
#  'king': 7824,
#  'ghost': 5896,
#  'scary': 12435,
#  'spooky': 13247,
#  'stephen': 13367,
#  'alien': 800,
#  'host': 6785,
#  'printz': 11242,
#  'pov': 11129,
#  'standalone': 13306,
#  'húmor': 6899,
#  'beach': 1636,
#  '1990s': 204,
#  'girly': 5944,
#  'helen': 6477,
#  'fielding': 5300,
#  'light': 8358,
#  'just': 7587,
#  'london': 8518,
#  '1800s': 117,
#  'boys': 2169,
#  'medal': 9103,
#  'holes': 6693,
#  'classroom': 3033,
#  'watched': 14885,
#  'lauren': 8133,
#  'weisberger': 14944,
#  'fashion': 5161,
#  'nyc': 10153,
#  'myth': 9714,
#  'classical': 3021,
#  'studies': 13480,
#  'ancient': 937,
#  'epics': 4793,
#  'homer': 6719,
#  'antiquity': 1042,
#  'greece': 6121,
#  'french': 5617,
#  'clásicos': 3096,
#  'fairy': 5074,
#  'tales': 13731,
#  'français': 5585,
#  'francais': 5553,
#  'fic': 5274,
#  'families': 5094,
#  'appalachia': 1078,
#  'homelessness': 6717,
#  'poverty': 11130,
#  'alaska': 755,
#  'nature': 9812,
#  'jon': 7500,
#  'krakauer': 7962,
#  'wilderness': 15036,
#  'environment': 4779,
#  'wanderlust': 14845,
#  'journalism': 7528,
#  'exploration': 5013,
#  'outdoors': 10393,
#  'revolution': 11943,
#  'dickens': 4080,
#  'charles': 2787,
#  'paris': 10541,
#  'jurassic': 7582,
#  'park': 10542,
#  'techno': 13837,
#  'crichton': 3591,
#  'michael': 9251,
#  'cloning': 3079,
#  'dinosaurs': 4119,
#  'giving': 5951,
#  'tree': 14265,
#  'edrd': 4544,
#  '314': 315,
#  'picturebooks': 10845,
#  'grisham': 6154,
#  'courtroom': 3513,
#  'legal': 8193,
#  'revenge': 11935,
#  'trials': 14274,
#  'calibre': 2464,
#  'lawyers': 8144,
#  'law': 8139,
#  'night': 9970,
#  'genocide': 5844,
#  'oprah': 10313,
#  'judaism': 7545,
#  'elie': 4623,
#  'wiesel': 15025,
#  'standalones': 13307,
#  'road': 12045,
#  'trip': 14296,
#  'paper': 10508,
#  'towns': 14183,
#  'genre': 5848,
#  'tale': 13726,
#  'goldman': 6010,
#  'fairytales': 5079,
#  'sword': 13659,
#  'laser': 8096,
#  'gangs': 5749,
#  'outsiders': 10402,
#  '40': 341,
#  'maze': 9027,
#  'runner': 12205,
#  'dashner': 3816,
#  'sciences': 12473,
#  'finance': 5345,
#  'economics': 4509,
#  'behavioral': 1692,
#  'educational': 4553,
#  'business': 2408,
#  'mathematics': 8975,
#  'reference': 11750,
#  'interesting': 7178,
#  'current': 3704,
#  'events': 4946,
#  'education': 4552,
#  'economic': 4508,
#  'econ': 4505,
#  'statistics': 13338,
#  'pop': 11048,
#  'society': 13074,
#  'money': 9484,
#  'nonfic': 10037,
#  'affairs': 664,
#  'management': 8799,
#  'essays': 4897,
#  'academic': 533,
#  'sociology': 13079,
#  'economy': 4512,
#  'frances': 5556,
#  'hodgson': 6679,
#  'burnett': 2395,
#  'spanish': 13178,
#  'colombian': 3183,
#  'colombia': 3182,
#  'gabriel': 5712,
#  'garcia': 5758,
#  'marquez': 8910,
#  'español': 4877,
#  'ireland': 7246,
#  'queer': 11480,
#  'oscar': 10370,
#  'wilde': 15034,
#  'irish': 7249,
#  'el': 4590,
#  'smut': 13042,
#  'dracula': 4320,
#  'terror': 13907,
#  'bram': 2194,
#  'stoker': 13398,
#  'nordic': 10062,
#  'noir': 10024,
#  'computer': 3283,
#  'hacker': 6252,
#  'bestsellers': 1776,
#  'lisbeth': 8413,
#  'salander': 12307,
#  'boyfriend': 2164,
#  'interested': 7177,
#  'kobo': 7915,
#  'fanfiction': 5108,
#  'boring': 2108,
#  'mf': 9236,
#  'annoying': 1009,
#  'bad': 1484,
#  'boy': 2161,
#  'erotik': 4844,
#  'trilogies': 14288,
#  'billionaires': 1852,
#  'pdf': 10622,
#  'naughty': 9814,
#  'intense': 7165,
#  'hero': 6519,
#  'angsty': 981,
#  'leidos': 8205,
#  'fav': 5178,
#  'congo': 3309,
#  'barbara': 1554,
#  'kingsolver': 7834,
#  'oprahs': 10315,
#  'colonialism': 3187,
#  'missionaries': 9375,
#  '2000s': 236,
#  'gay': 5793,
#  'glbt': 5962,
#  'essay': 4896,
#  'lol': 8513,
#  'david': 3828,
#  'sedaris': 12552,
#  'preschool': 11193,
#  'imagination': 6980,
#  'maurice': 9006,
#  'sendak': 12601,
#  'caldecott': 2457,
#  'storytime': 13426,
#  'alexandre': 790,
#  'dumas': 4404,
#  'pulitzers': 11412,
#  'mccarthy': 9046,
#  'end': 4703,
#  'apocalypse': 1066,
#  'cormac': 3448,
#  'disappointing': 4138,
#  'celebrity': 2696,
#  'feminist': 5237,
#  'bios': 1890,
#  'television': 13869,
#  'tina': 14065,
#  'fey': 5260,
#  'tearjerker': 13823,
#  'nicolas': 9957,
#  'tearjerkers': 13824,
#  'shopping': 12823,
#  'brain': 2185,
#  'candy': 2510,
#  'shopaholic': 12821,
#  'kinsella': 7840,
#  'sophie': 13128,
#  'chiclit': 2864,
#  'victor': 14696,
#  'picks': 10834,
#  'downs': 4311,
#  'adoption': 621,
#  'secrets': 12548,
#  'kim': 7800,
#  'edwards': 4556,
#  'disabilities': 4132,
#  'twins': 14393,
#  'heartbreaking': 6448,
#  'jojo': 7496,
#  'moyes': 9591,
#  'ugly': 14422,
#  'suicide': 13548,
#  'assisted': 1266,
#  'mitch': 9393,
#  'albom': 763,
#  'lessons': 8259,
#  'detroit': 4022,
#  'michigan': 9258,
#  'sexuality': 12666,
#  'hermaphrodite': 6516,
#  'gender': 5824,
#  'missouri': 9380,
#  'immigrant': 6986,
#  'experience': 5005,
#  'amy': 909,
#  'tan': 13751,
#  'mothers': 9561,
#  'daughters': 3823,
#  'immigration': 6988,
#  'china': 2898,
#  'chinese': 2901,
#  'shared': 12723,
#  'atwood': 1325,
#  'ann': 997,
#  'brashares': 2202,
#  'sisterhood': 12940,
#  'traveling': 14253,
#  'pants': 10503,
#  'ýa': 15448,
#  'controversial': 3399,
#  'russian': 12226,
#  'vladimir': 14766,
#  'nabokov': 9737,
#  'disturbing': 4184,
#  'wizard': 15117,
#  'oz': 10432,
#  'retelling': 11918,
#  'wicked': 15013,
#  'gregory': 6135,
#  'maguire': 8734,
#  'retellings': 11919,
#  'fairytale': 5078,
#  'government': 6057,
#  'investigators': 7223,
#  'lawyer': 8143,
#  'organized': 10342,
#  'memphis': 9163,
#  'firms': 5379,
#  'captivity': 2540,
#  'abduction': 486,
#  'kidnapping': 7778,
#  'emma': 4672,
#  'donoghue': 4266,
#  'class': 3017,
#  '17th': 114,
#  'denmark': 3961,
#  'hamlet': 6295,
#  'masterworks': 8960,
#  'nebula': 9840,
#  'sff': 12673,
#  'ciencia': 2965,
#  'ficción': 5281,
#  'herbert': 6506,
#  'dune': 4413,
#  'entrepreneurship': 4770,
#  'communication': 3246,
#  'professional': 11285,
#  'gladwell': 5955,
#  'behavior': 1691,
#  'leadership': 8162,
#  'malcolm': 8778,
#  'career': 2555,
#  'advertising': 646,
#  'human': 6845,
#  'psych': 11363,
#  'growth': 6174,
#  'work': 15169,
#  'learning': 8170,
#  'marketing': 8896,
#  'design': 3995,
#  'biografie': 1870,
#  'steve': 13375,
#  'jobs': 7472,
#  'people': 10683,
#  'technology': 13839,
#  'innovation': 7118,
#  'computers': 3284,
#  'biografias': 1869,
#  'paused': 10610,
#  'tech': 13831,
#  'ibooks': 6908,
#  'apple': 1085,
#  'startup': 13331,
#  'cuba': 3672,
#  'fishing': 5388,
#  'ernest': 4838,
#  'hemingway': 6493,
#  'laureates': 8129,
#  'sea': 12520,
#  'feel': 5218,
#  'faith': 5080,
#  'heaven': 6455,
#  'gables': 5710,
#  'orphans': 10359,
#  'montgomery': 9507,
#  'fairies': 5070,
#  'nephilim': 9881,
#  'fae': 5062,
#  '2002': 238,
#  'rebecca': 11687,
#  'wells': 14952,
#  'louisiana': 8569,
#  '18th': 137,
#  'diana': 4066,
#  'gabaldon': 5708,
#  'outlander': 10395,
#  'highlanders': 6572,
#  'highlander': 6571,
#  'scotland': 12493,
#  ...}

# %%
doc = 0
feature_index = tags_matrix[doc,:].nonzero()[1]
tfidf_scores = zip(feature_index, [tags_matrix[doc, x] for x in feature_index])

# %%
books_metadata['tags'][0]
# Out:
# 'my-books read-2012 coming-of-age borrowed my-library i-own read-in-2012 read-more-than-once ebooks audio read-2011 action thriller series reviewed sci-fi-fantasy favorite favorite-books read-in-2013 distopian owned adventure default fantasy favorites hunger-games trilogy science-fiction suspense action-adventure audiobook sf ya-fantasy teen-fiction favourite-books favorite-series shelfari-favorites 5-stars teen ebook favs fantasy-sci-fi favourites dystopian-fiction faves books-i-own sci-fi finished read-in-2014 young-adult dystopia love the-hunger-games fiction reread distopia my-favorites post-apocalyptic future love-triangle suzanne-collins all-time-favorites dystopias novels books contemporary finished-series to-buy completed-series scifi drama english read-in-2011 young-adult-fiction scifi-fantasy currently-reading survival ya-dystopian ya-lit library novel favourite 2012-reads e-book read-in-2010 to-read dystopian ya-books ya-fiction futuristic book-club ya loved audiobooks 5-star re-read own-it speculative-fiction kindle romance'

# %%
feature_names = tfidf.get_feature_names_out()
tfidf_scores_sorted=[]
for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
    tfidf_scores_sorted.append([w,s])
    print(w,s)
tfidf_scores_sorted
# Out:
# romance 0.04199622977855118
# kindle 0.02671163235919224
# speculative 0.07251109380641134
# star 0.07502456600504018
# audiobooks 0.031266504133500087
# loved 0.0821114576482351
# club 0.04099937951732761
# futuristic 0.10222335450570373
# 2010 0.061259574090483174
# book 0.05075185270695867
# reads 0.037744265378818725
# novel 0.04076188141812142
# lit 0.0384369552648043
# survival 0.09227270649072088
# reading 0.02298125553548972
# currently 0.023230810810032552
# english 0.042713331941499955
# drama 0.049316044695898904
# scifi 0.11833114913195372
# completed 0.08957555690286702
# buy 0.025624979389037798
# contemporary 0.036229004568697314
# novels 0.03321781659626496
# dystopias 0.11595489846127827
# time 0.04811754784979944
# collins 0.16278266572379443
# suzanne 0.1689599755316416
# triangle 0.09451559019735939
# future 0.10148334660793373
# apocalyptic 0.09414362016630412
# post 0.09032041817820313
# distopia 0.12415576195547645
# reread 0.06447599331006632
# love 0.1182182733789269
# dystopia 0.08248694113279854
# adult 0.050274307002089944
# young 0.08955243313353398
# 2014 0.036439973564639086
# finished 0.09326301234683844
# faves 0.07285947769502388
# dystopian 0.24386594089904134
# favourites 0.032486803170974646
# favs 0.08061050008143493
# ebook 0.027553019442237803
# stars 0.04490253515145797
# shelfari 0.04540261740206128
# favourite 0.15601206548963692
# teen 0.12105581823431902
# ya 0.3015041597733736
# sf 0.0731713759624739
# audiobook 0.030042481278043362
# suspense 0.054037901047721895
# fiction 0.1591090625519843
# science 0.049455656469208666
# trilogy 0.09256582324936079
# games 0.2870704991769456
# hunger 0.35494319892391674
# favorites 0.09132035307515733
# default 0.027116021505186456
# adventure 0.09046123394965591
# owned 0.022827805574358255
# distopian 0.1220806390446814
# 2013 0.03922648213642432
# favorite 0.10421703627009953
# fantasy 0.20939881583030975
# fi 0.14959410308634513
# sci 0.14867724045144692
# reviewed 0.055071054401527424
# series 0.15108275939587956
# thriller 0.0527154420006203
# action 0.11140526633957136
# 2011 0.10322233000148891
# audio 0.031519427015044746
# ebooks 0.030064442972355623
# library 0.046563967995408816
# borrowed 0.04532259807071983
# age 0.06718730323616849
# coming 0.06839317342500893
# 2012 0.13188945761251697
# read 0.22716233611785355
# books 0.13629740167071214
# [['romance', 0.04199622977855118],
#  ['kindle', 0.02671163235919224],
#  ['speculative', 0.07251109380641134],
#  ['star', 0.07502456600504018],
#  ['audiobooks', 0.031266504133500087],
#  ['loved', 0.0821114576482351],
#  ['club', 0.04099937951732761],
#  ['futuristic', 0.10222335450570373],
#  ['2010', 0.061259574090483174],
#  ['book', 0.05075185270695867],
#  ['reads', 0.037744265378818725],
#  ['novel', 0.04076188141812142],
#  ['lit', 0.0384369552648043],
#  ['survival', 0.09227270649072088],
#  ['reading', 0.02298125553548972],
#  ['currently', 0.023230810810032552],
#  ['english', 0.042713331941499955],
#  ['drama', 0.049316044695898904],
#  ['scifi', 0.11833114913195372],
#  ['completed', 0.08957555690286702],
#  ['buy', 0.025624979389037798],
#  ['contemporary', 0.036229004568697314],
#  ['novels', 0.03321781659626496],
#  ['dystopias', 0.11595489846127827],
#  ['time', 0.04811754784979944],
#  ['collins', 0.16278266572379443],
#  ['suzanne', 0.1689599755316416],
#  ['triangle', 0.09451559019735939],
#  ['future', 0.10148334660793373],
#  ['apocalyptic', 0.09414362016630412],
#  ['post', 0.09032041817820313],
#  ['distopia', 0.12415576195547645],
#  ['reread', 0.06447599331006632],
#  ['love', 0.1182182733789269],
#  ['dystopia', 0.08248694113279854],
#  ['adult', 0.050274307002089944],
#  ['young', 0.08955243313353398],
#  ['2014', 0.036439973564639086],
#  ['finished', 0.09326301234683844],
#  ['faves', 0.07285947769502388],
#  ['dystopian', 0.24386594089904134],
#  ['favourites', 0.032486803170974646],
#  ['favs', 0.08061050008143493],
#  ['ebook', 0.027553019442237803],
#  ['stars', 0.04490253515145797],
#  ['shelfari', 0.04540261740206128],
#  ['favourite', 0.15601206548963692],
#  ['teen', 0.12105581823431902],
#  ['ya', 0.3015041597733736],
#  ['sf', 0.0731713759624739],
#  ['audiobook', 0.030042481278043362],
#  ['suspense', 0.054037901047721895],
#  ['fiction', 0.1591090625519843],
#  ['science', 0.049455656469208666],
#  ['trilogy', 0.09256582324936079],
#  ['games', 0.2870704991769456],
#  ['hunger', 0.35494319892391674],
#  ['favorites', 0.09132035307515733],
#  ['default', 0.027116021505186456],
#  ['adventure', 0.09046123394965591],
#  ['owned', 0.022827805574358255],
#  ['distopian', 0.1220806390446814],
#  ['2013', 0.03922648213642432],
#  ['favorite', 0.10421703627009953],
#  ['fantasy', 0.20939881583030975],
#  ['fi', 0.14959410308634513],
#  ['sci', 0.14867724045144692],
#  ['reviewed', 0.055071054401527424],
#  ['series', 0.15108275939587956],
#  ['thriller', 0.0527154420006203],
#  ['action', 0.11140526633957136],
#  ['2011', 0.10322233000148891],
#  ['audio', 0.031519427015044746],
#  ['ebooks', 0.030064442972355623],
#  ['library', 0.046563967995408816],
#  ['borrowed', 0.04532259807071983],
#  ['age', 0.06718730323616849],
#  ['coming', 0.06839317342500893],
#  ['2012', 0.13188945761251697],
#  ['read', 0.22716233611785355],
#  ['books', 0.13629740167071214]]

# %%
tfidf_scores_sorted_df=pd.DataFrame(tfidf_scores_sorted)
tfidf_scores_sorted_df.columns=['token','val']
tfidf_scores_sorted_df.sort_values(by='val',ascending=False,inplace=True)
tfidf_scores_sorted_df.head(20)
# Out:
#         token       val
# 56     hunger  0.354943
# 48         ya  0.301504
# 55      games  0.287070
# 40  dystopian  0.243866
# 79       read  0.227162
# 64    fantasy  0.209399
# 26    suzanne  0.168960
# 25    collins  0.162783
# 52    fiction  0.159109
# 46  favourite  0.156012
# 68     series  0.151083
# 65         fi  0.149594
# 66        sci  0.148677
# 80      books  0.136297
# 78       2012  0.131889
# 31   distopia  0.124156
# 61  distopian  0.122081
# 47       teen  0.121056
# 18      scifi  0.118331
# 33       love  0.118218

# %% [markdown]
# ¿Que palabras comunes se les ocurre que podríamos sacar?

# %% [markdown]
# ### Similitud Coseno

# %% [markdown]
# <img src="similitud_coseno.jpg" align="center" width="60%"/>

# %% [markdown]
# Así como vimos la distancia euclideana y el coeficiente de Pearson para estimar la similitud entre dos personas o ítems, existe otra medida muy utilizada llamada *similitud coseno*. En este caso la utilizaremos para estimar la similitud entre los contenidos de los ítems.
#
# La imagen muestra la similitud coseno en dos dimensiones. Si dos vectores de datos son cercanos, el ángulo entre estos dos vectores es pequeño y la similitud coseno será alta. En el extremo, dos vectores iguales tendrán un ángulo de 0 grados, un coseno de 1, y una similitud coseno también de 1.
#
# Naturalmente, podemos llevar el concepto para N dimensiones.

# %%
similarity_matrix = cosine_similarity(tags_matrix,tags_matrix)
similarity_matrix
# Out:
# array([[1.        , 0.38961343, 0.40894373, ..., 0.09091467, 0.16148787,
#         0.03602845],
#        [0.38961343, 1.        , 0.37207812, ..., 0.0886315 , 0.16692497,
#         0.04592596],
#        [0.40894373, 0.37207812, 1.        , ..., 0.05919159, 0.09024158,
#         0.02882952],
#        ...,
#        [0.09091467, 0.0886315 , 0.05919159, ..., 1.        , 0.05409486,
#         0.12427748],
#        [0.16148787, 0.16692497, 0.09024158, ..., 0.05409486, 1.        ,
#         0.11579571],
#        [0.03602845, 0.04592596, 0.02882952, ..., 0.12427748, 0.11579571,
#         1.        ]])

# %%
def recommend_books_based_on_plot(book_input,n=15):
    book_index = books_metadata.loc[books_metadata.original_title==book_input,:].index[0]

    #get similarity values with other books
    #similarity_score is the list of index and similarity matrix
    similarity_score = list(enumerate(similarity_matrix[book_index]))

    #sort in descending order the similarity score of book inputted with all the other books
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)

    # Get the scores of the 15 most similar books. Ignore the first book.
    similarity_score = similarity_score[1:n]

    #return book names using the mapping series
    book_indices = [i[0] for i in similarity_score]

    return (books_metadata[['original_title','authors','tags']].iloc[book_indices])

# %%
recommend_books_based_on_plot('Nineteen Eighty-Four',10)
# Out:
#                                 original_title  \
# 54                             Brave New World
# 13                  Animal Farm: A Fairy Story
# 47                              Fahrenheit 451
# 27                          Lord of the Flies
# 70     Frankenstein; or, The Modern Prometheus
# 172                         A Clockwork Orange
# 808  Brave New World/Brave New World Revisited
# 7                       The Catcher in the Rye
# 845                         Animal Farm & 1984
#
#                                                authors  \
# 54                                       Aldous Huxley
# 13                                       George Orwell
# 47                                        Ray Bradbury
# 27                                     William Golding
# 70   Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 172                                    Anthony Burgess
# 808                Aldous Huxley, Christopher Hitchens
# 7                                        J.D. Salinger
# 845                George Orwell, Christopher Hitchens
#
#                                                   tags
# 54   my-books owned-books my-library banned-books i...
# 13   my-books school-reads owned-books borrowed my-...
# 47   my-books school-reads owned-books borrowed my-...
# 27   my-books school-reads coming-of-age owned-book...
# 70   my-books school-reads owned-books my-library i...
# 172  2015-reading-challenge my-books owned-books ba...
# 808  my-books owned-books my-library i-own classics...
# 7    america my-books school-reads coming-of-age ow...
# 845  philosophical best my-books school-reads owned...

# %%
recommend_books_based_on_plot('The Hobbit')
# Out:
#                                      original_title  \
# 3520                       Neverwhere Graphic Novel
# 963            The Hobbit and The Lord of the Rings
# 154                                  The Two Towers
# 18                       The Fellowship of the Ring
# 7421                                       Coraline
# 6                The Hobbit or There and Back Again
# 160                          The Return of the King
# 8373                            Darth Vader and Son
# 6737                               The Hedge Knight
# 1697            The Dark Tower: The Gunslinger Born
# 610                                The Silmarillion
# 188                           The Lord of the Rings
# 8382           A Wrinkle in Time: The Graphic Novel
# 3634  Bone: The Complete Cartoon Epic in One Volume
#
#                                                 authors  \
# 3520               Mike Carey, Glenn Fabry, Neil Gaiman
# 963                                      J.R.R. Tolkien
# 154                                      J.R.R. Tolkien
# 18                                       J.R.R. Tolkien
# 7421                      Neil Gaiman, P. Craig Russell
# 6                                        J.R.R. Tolkien
# 160                                      J.R.R. Tolkien
# 8373                                      Jeffrey Brown
# 6737      Ben Avery, Mike S. Miller, George R.R. Martin
# 1697  Peter David, Robin Furth, Jae Lee, Richard Isa...
# 610    J.R.R. Tolkien, Christopher Tolkien, Ted Nasmith
# 188                                      J.R.R. Tolkien
# 8382                     Hope Larson, Madeleine L'Engle
# 3634                                         Jeff Smith
#
#                                                    tags
# 3520  graphic-novels-manga my-books vertigo fantasy-...
# 963   fantasy-scifi my-library i-own classics person...
# 154   my-books fantasy-scifi owned-books my-library ...
# 18    my-books fantasy-scifi owned-books my-library ...
# 7421  my-books coming-of-age library-books owned-boo...
# 6     my-books fantasy-scifi owned-books my-library ...
# 160   my-books fantasy-scifi owned-books my-library ...
# 8373  quadrinhos read-2012 pop-culture space library...
# 6737  2015-reading-challenge my-books got fantasy-sc...
# 1697  graphic-novels-manga my-books read-in-2008 wes...
# 610   never-finished my-books unread fantasy-scifi o...
# 188   my-books fantasy-scifi owned-books my-library ...
# 8382  2017-read graphic-novels-manga space library-b...
# 3634  never-finished graphic-novels-manga my-books f...

# %% [markdown]
# Para obtener recomendaciones más diversas, podríamos dejar afuera las novelas del mismo autor de la novela target.

# %% [markdown]
# ## Ejemplo práctico de un SR basado en filtros colaborativos: Librería Surprise

# %% [markdown]
# Tenemos que crear un objeto dataset para trabajar con Surprise. Este dataset contiene los siguientes elementos:
# 1. Los IDs de los usuarios
# 2. Los IDs de cada ítem (en este caso, de cada libro)
# 3. El rating correspondiente (en este caso, en una escala del 1 al 5)

# %%
from surprise import Dataset
from surprise import Reader

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings_data[['user_id', 'book_id', 'rating']], reader)

# %% [markdown]
# ### Entrenamos un modelo SVD con crossvalidation

# %% [markdown]
# Podemos entrenar con cross-validation un modelo que realiza SVD (descomposición de valor singular o Singular Value Decomposition) para construir un sistema de recomendación. SVD es un algoritmo de factorización de matrices que puede utilizarse para sistemas de recomendación.
#
# Los sistemas de recomendación que utilizan la factorización matricial suelen seguir un patrón en el que una matriz de puntuaciones o ratings se factoriza en un producto de matrices que representan factores latentes para los ítems (en este caso, libros) y los usuarios. Funciona con la técnica de factorización matricial que vimos la clase pasada.

# %%
from surprise import SVD
from surprise.model_selection import cross_validate

svd = SVD(verbose=True, n_epochs=10)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8560  0.8566  0.8556  0.8560  0.0004
# MAE (testset)     0.6751  0.6756  0.6751  0.6752  0.0002
# Fit time          3.05    3.38    3.38    3.27    0.16
# Test time         1.42    1.60    1.66    1.56    0.10
# {'test_rmse': array([0.85598642, 0.8565825 , 0.85557451]),
#  'test_mae': array([0.67507586, 0.67556842, 0.67509726]),
#  'fit_time': (3.046085834503174, 3.3755037784576416, 3.38267183303833),
#  'test_time': (1.420814037322998, 1.603020191192627, 1.6629512310028076)}

# %% [markdown]
# También podemos entrenar el modelo en todo el conjunto de datos utilizando el método fit después de convertir el objeto Dataset en un objeto Surprise Trainset utilizando el método build_full_trainset.

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9

# %% [markdown]
# Ahora podemos realizar predicciones para un ID de un libro específico, con el método predict.

# %%
svd.predict(uid=10, iid=100)
# Out:
# Prediction(uid=10, iid=100, r_ui=None, est=4.057148878995296, details={'was_impossible': False})

# %% [markdown]
# Tomemos de ejemplo un fanático confeso de los libros de Dan Brown (autor de El Código Da Vinci). Observemos sus puntuaciones a los libros de dicho autor:

# %%
books_metadata.loc[books_metadata.authors.str.contains('Dan Brown'),:]
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 8        9       960           960   3338963          311  1416524797
# 25      26       968           968   2982101          350   307277674
# 144    145       976           976   3135896          180   671027387
# 169    170     11125         11125     40195          185   552151696
# 200    201   6411961       6411961   6600281          208   385504225
# 239    240  17212231      17212231  23841765          235   385537859
# 4495  4496    643301        643301  24585562            6   593054601
#
#             isbn13    authors  original_publication_year     original_title  \
# 8     9.781417e+12  Dan Brown                     2000.0   Angels & Demons
# 25    9.780307e+12  Dan Brown                     2003.0  The Da Vinci Code
# 144   9.780671e+12  Dan Brown                     2001.0    Deception Point
# 169   9.780552e+12  Dan Brown                     1998.0   Digital Fortress
# 200   9.780386e+12  Dan Brown                     2009.0    The Lost Symbol
# 239   9.780386e+12  Dan Brown                     2013.0            Inferno
# 4495  9.780593e+12  Dan Brown                     2003.0                NaN
#
#       ... work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 8     ...            2078754                   25112      77841     145740
# 25    ...            1557292                   41560      71345     126493
# 144   ...             479733                    7798      14380      45006
# 169   ...             447503                    7538      16592      47507
# 200   ...             404982                   24199      11293      40545
# 239   ...             345560                   33700       7261      26077
# 4495  ...              18765                     476        254        636
#
#       ratings_3  ratings_4  ratings_5  \
# 8        458429     716569     680175
# 25       340790     539277     479387
# 144      143182     160819     116346
# 169      136196     144029     103179
# 200      120122     136545      96477
# 239       89237     128374      94611
# 4495       2797       6648       8430
#
#                                               image_url  \
# 8     https://images.gr-assets.com/books/1303390735m...
# 25    https://images.gr-assets.com/books/1303252999m...
# 144   https://s.gr-assets.com/assets/nophoto/book/11...
# 169   https://images.gr-assets.com/books/1360095966m...
# 200   https://images.gr-assets.com/books/1358274396m...
# 239   https://images.gr-assets.com/books/1397093185m...
# 4495  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                         small_image_url  \
# 8     https://images.gr-assets.com/books/1303390735s...
# 25    https://images.gr-assets.com/books/1303252999s...
# 144   https://s.gr-assets.com/assets/nophoto/book/50...
# 169   https://images.gr-assets.com/books/1360095966s...
# 200   https://images.gr-assets.com/books/1358274396s...
# 239   https://images.gr-assets.com/books/1397093185s...
# 4495  https://s.gr-assets.com/assets/nophoto/book/50...
#
#                                                    tags
# 8     my-books 2006 owned-books borrowed my-library ...
# 25    my-books 2006 owned-books borrowed my-library ...
# 144   action-thriller my-books 2006 owned-books tech...
# 169   action-thriller my-books 2006 owned-books tech...
# 200   my-books owned-books borrowed my-library i-own...
# 239   my-books inferno nook owned-books 2013-books b...
# 4495  my-books unread owned-books my-library not-int...
#
# [7 rows x 24 columns]

# %%
libros_db=books_metadata.loc[books_metadata.authors.str.contains('Dan Brown'),'id'].values
libros_db
# Out:
# array([   9,   26,  145,  170,  201,  240, 4496])

# %%
libros_leidos_usuario_db=ratings_data.loc[(ratings_data.user_id==18313)&(ratings_data.book_id.isin(libros_db)),:]
libros_leidos_usuario_db
# Out:
#       book_id  user_id  rating
# 843         9    18313       5
# 2539       26    18313       5

# %% [markdown]
# Vemos que en general hace una muy buena evaluación de los libros de DB

# %%
libros_db[~np.isin(libros_db,libros_leidos_usuario_db)]
# Out:
# array([ 145,  170,  201,  240, 4496])

# %%
pendientes_db=libros_db[~np.isin(libros_db,libros_leidos_usuario_db)]
pred=[]
for libro in pendientes_db:
    pred.append(svd.predict(uid=18313, iid=libro).est)

media_db=ratings_data.loc[ratings_data.book_id.isin(libros_db),"rating"].mean()    
print(f'Media ratings libros DB: {round(media_db,2)}')    
print(f'Media ratings puntuación estimada libros no leídos de DB por usuario 18313: {round(np.array(pred).mean(),2)}')
# Out:
# Media ratings libros DB: 3.44
# Media ratings puntuación estimada libros no leídos de DB por usuario 18313: 3.67

# %% [markdown]
# Vemos que la puntuación promedio estimada por nuestro modelo para los libros aún no leídos de Dan Brown es superior al promedio.
# <br>
#
# *Dan Brown es un autor muy popular y por eso quizás no vemos una diferencia sustancial entre el promedio estimado por nuestro usuario y el promedio general. Podría verificarse la diferencia entre ambos promedios tomando como referencia otro autor menos popular*.

# %% [markdown]
# ### Generando recomendaciones

# %%
import difflib
import random

def get_book_id(book_title, metadata):
    
    existing_titles = list(metadata['title'].values)
    closest_titles = difflib.get_close_matches(book_title, existing_titles)
    book_id = metadata[metadata['title'] == closest_titles[0]]['id'].values[0]
    return book_id

def get_book_info(book_id, metadata):
    
    book_info = metadata[metadata['id'] == book_id][['id', 'isbn', 
                                                    'authors', 'title', 'original_title']]
    return book_info.to_dict(orient='records')

def predict_review(user_id, book_title, model, metadata):
    
    book_id = get_book_id(book_title, metadata)
    review_prediction = model.predict(uid=user_id, iid=book_id)
    return review_prediction.est

def generate_recommendation(user_id, model, metadata, thresh=4):
    
    book_titles = list(metadata['title'].values)
    random.shuffle(book_titles)
    
    for book_title in book_titles:
        rating = predict_review(user_id, book_title, model, metadata)
        if rating >= thresh:
            book_id = get_book_id(book_title, metadata)
            return get_book_info(book_id, metadata)

# %% [markdown]
# La función generate_recommendation genera una recomendación de libros para un usuario iterando a través de la lista de títulos de libros y prediciendo las valoraciones de los usuarios para cada título hasta que encuentra un libro con una valoración igual o superior al umbral especificado que lo califica para ser recomendado a un usuario.

# %%
# %%time
generate_recommendation(18313, svd, books_metadata, 4.8)
# Out:
# CPU times: user 3 s, sys: 9.89 ms, total: 3.01 s
# Wall time: 3.1 s
# [{'id': 3082,
#   'isbn': '1563891379',
#   'authors': 'Neil Gaiman, Jill Thompson, Vince Locke, Peter Straub',
#   'title': 'Brief Lives (The Sandman #7)',
#   'original_title': 'The Sandman: Brief Lives'}]

# %% [markdown]
# ### Visualizando las similitudes entre los libros utilizando t-SNE

# %%
svd.qi.shape
# Out:
# (10000, 100)

# %% [markdown]
# Ahora podemos apreciar la similitud entre los libros a partir de la matriz de factorización resultante luego de aplicar el algoritmo SVD.
#
# Esta matriz de 10.000 x 100 tiene un vector de 100 dimensiones para cada libro, que son demasiadas dimensiones para que podamos visualizarlas intuitivamente, pero podemos utilizar una técnica de reducción de la dimensionalidad para representar cada libro como un punto bidimensional en el espacio.
#
# Podemos utilizar t-SNE (t-Distributed Stochastic Neighbors Embedding, una alternativa a PCA) para representar cada libro como un punto bidimensional.

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, n_iter=500, verbose=3, random_state=1)
books_embedding = tsne.fit_transform(svd.qi)
projection = pd.DataFrame(columns=['x', 'y'], data=books_embedding)
projection['title'] = books_metadata['original_title']
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.000s...
# [t-SNE] Computed neighbors for 10000 samples in 0.450s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.233667
# [t-SNE] Computed conditional probabilities in 0.146s
# [t-SNE] Iteration 50: error = 97.0348206, gradient norm = 0.0568880 (50 iterations in 3.090s)
# [t-SNE] Iteration 100: error = 98.1434097, gradient norm = 0.0497454 (50 iterations in 3.404s)
# [t-SNE] Iteration 150: error = 99.1252747, gradient norm = 0.0735304 (50 iterations in 3.161s)
# [t-SNE] Iteration 200: error = 98.9208374, gradient norm = 0.0581026 (50 iterations in 3.443s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 4
#       1 from sklearn.manifold import TSNE
#       3 tsne = TSNE(n_components=2, n_iter=500, verbose=3, random_state=1)
# ----> 4 books_embedding = tsne.fit_transform(svd.qi)
#       5 projection = pd.DataFrame(columns=['x', 'y'], data=books_embedding)
#       6 projection['title'] = books_metadata['original_title']
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:1111, in TSNE.fit_transform(self, X, y)
#    1090 """Fit X into an embedded space and return that transformed output.
#    1091
#    1092 Parameters
#    (...)
#    1108     Embedding of the training data in low-dimensional space.
#    1109 """
#    1110 self._check_params_vs_input(X)
# -> 1111 embedding = self._fit(X)
#    1112 self.embedding_ = embedding
#    1113 return self.embedding_
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:1001, in TSNE._fit(self, X, skip_num_points)
#     995 # Degrees of freedom of the Student's t-distribution. The suggestion
#     996 # degrees_of_freedom = n_components - 1 comes from
#     997 # "Learning a Parametric Embedding by Preserving Local Structure"
#     998 # Laurens van der Maaten, 2009.
#     999 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1001 return self._tsne(
#    1002     P,
#    1003     degrees_of_freedom,
#    1004     n_samples,
#    1005     X_embedded=X_embedded,
#    1006     neighbors=neighbors_nn,
#    1007     skip_num_points=skip_num_points,
#    1008 )
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:1053, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1050 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1051 # higher learning rate controlled via the early exaggeration parameter
#    1052 P *= self.early_exaggeration
# -> 1053 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1054 if self.verbose:
#    1055     print(
#    1056         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1057         % (it + 1, kl_divergence)
#    1058     )
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:402, in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     399 # only compute the error when needed
#     400 kwargs["compute_error"] = check_convergence or i == n_iter - 1
# --> 402 error, grad = objective(p, *args, **kwargs)
#     404 inc = update * grad < 0.0
#     405 dec = np.invert(inc)
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:283, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     280 indptr = P.indptr.astype(np.int64, copy=False)
#     282 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 283 error = _barnes_hut_tsne.gradient(
#     284     val_P,
#     285     X_embedded,
#     286     neighbors,
#     287     indptr,
#     288     grad,
#     289     angle,
#     290     n_components,
#     291     verbose,
#     292     dof=degrees_of_freedom,
#     293     compute_error=compute_error,
#     294     num_threads=num_threads,
#     295 )
#     296 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     297 grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
import plotly.express as px

fig = px.scatter(
    projection, x='x', y='y'
)
fig.show()

report = dp.Report(dp.Plot(fig) ) #Create a report
# report.publish(name='books_scatter_plot', open=True, visibility='PUBLIC') #Publish the report

# %% [markdown]
# Podemos ver que los puntos que representan los 10.000 libros parecen seguir una distribución normal bidimensional. Podemos explicar esta distribución de la siguiente forma:
#
# - Algunos libros pueden ser populares en general entre un amplio abanico de audiencias y, por tanto, corresponder a puntos en el centro de este diagrama de dispersión.
# - Otros libros pueden pertenecer a géneros muy específicos, como las novelas de vampiros, de misterio o románticas, que son populares entre un público concreto. Estos libros pueden corresponder a puntos alejados del centro del diagrama.

# %%
import datapane as dp

def plot_books(titles, plot_name):
    
    book_indices = []
    for book in titles:
        book_indices.append(get_book_id(book, books_metadata)-1)
        
    book_vector_df = projection.iloc[book_indices]
    
    fig = px.scatter(
    book_vector_df, x='x', y='y', text='title',
    )
    fig.show()
    
    report = dp.Report(dp.Plot(fig) ) #Create a report
#     report.publish(name=plot_name, open=True, visibility='PUBLIC') #Publish the report

# %% [markdown]
# ¿Qué pasa si observamos algunos libros específicos? ¿Su similitud de características se ve reflejada en el nuevo espacio de dimensiones?

# %%
books = list(books_metadata['title'][:30])
plot_books(books, plot_name='books_embedding')

# %%
from collections import defaultdict
from surprise import Dataset, SVD

def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
algo = SVD()
algo.fit(trainset)

# %%
# Predice los ratings para todo par (u, i) que no aparece en train
# testset = trainset.build_anti_testset()
# predictions = algo_baseline.test(testset)

# Recomendamos usar un subsample porque las combinaciones de libros/usuarios que no aparecen en el set de
# train es muy grande!

# %%
#Predecimos los puntajes de los libros no leídos por el usuario amante de DB
libros_leidos_usuario=ratings_data.loc[(ratings_data.user_id==18313),'book_id']
libros_no_leidos_usuario=ratings_data.loc[~ratings_data.book_id.isin(libros_leidos_usuario),'book_id'].unique()

pred=[]
for libro in libros_no_leidos_usuario:
    pred.append(svd.predict(uid=18313, iid=libro))

# %%
pred
# Out:
# [Prediction(uid=18313, iid=6, r_ui=None, est=4.055893198586564, details={'was_impossible': False}),
#  Prediction(uid=18313, iid
details={'was_impossible': False}),
#  Prediction(uid=18313, iid=570, r_ui=None, est=4.244554254073792, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=571, r_ui=None, est=3.6922951501550636, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=572, r_ui=None, est=4.102766043965457, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=573, r_ui=None, est=3.4988066259045745, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=574, r_ui=None, est=4.003515664848212, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=575, r_ui=None, est=3.794252311697692, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=576, r_ui=None, est=3.886942011409846, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=577, r_ui=None, est=3.897608249546937, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=578, r_ui=None, est=3.239438088699242, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=579, r_ui=None, est=4.096280236769537, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=580, r_ui=None, est=4.286858575045667, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=581, r_ui=None, est=4.092936727611327, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=582, r_ui=None, est=3.4053021161356374, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=583, r_ui=None, est=3.514826489989443, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=584, r_ui=None, est=3.9384438811888867, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=585, r_ui=None, est=4.437609775049371, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=586, r_ui=None, est=3.7911329902455457, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=587, r_ui=None, est=3.904045778622134, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=588, r_ui=None, est=3.8842757384753392, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=589, r_ui=None, est=3.9926987251672585, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=590, r_ui=None, est=3.8606541444720386, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=591, r_ui=None, est=4.117688301447191, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=592, r_ui=None, est=4.299634041844679, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=593, r_ui=None, est=4.097477731824686, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=594, r_ui=None, est=3.8206453330533257, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=595, r_ui=None, est=3.584893260215999, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=596, r_ui=None, est=3.4999105036133784, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=598, r_ui=None, est=4.135546455559648, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=599, r_ui=None, est=4.074993240398515, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=600, r_ui=None, est=3.393711035431694, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=601, r_ui=None, est=4.045233631884793, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=602, r_ui=None, est=4.269787929600845, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=603, r_ui=None, est=4.39094971044193, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=604, r_ui=None, est=3.8121693237918284, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=605, r_ui=None, est=3.8396936279887863, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=606, r_ui=None, est=3.5257750300797572, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=607, r_ui=None, est=3.681121068902808, details={'was_impossible': False}),
# ...
#  Prediction(uid=18313, iid=1010, r_ui=None, est=4.82719414035474, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1011, r_ui=None, est=4.2313160600838104, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1012, r_ui=None, est=4.113779194885539, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1013, r_ui=None, est=4.0481182095719, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1014, r_ui=None, est=3.96818774072578, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1015, r_ui=None, est=3.876117639159107, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1016, r_ui=None, est=3.840441104807659, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1017, r_ui=None, est=4.0232045180202265, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1018, r_ui=None, est=4.2158605676194085, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1019, r_ui=None, est=3.9960149734580925, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1020, r_ui=None, est=4.035053227551871, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1021, r_ui=None, est=4.191927633321395, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1022, r_ui=None, est=4.65297466161719, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1023, r_ui=None, est=4.065912125986975, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1024, r_ui=None, est=3.838184514861392, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1025, r_ui=None, est=3.661637509194954, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1026, r_ui=None, est=4.281118688433374, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1027, r_ui=None, est=4.145271521022263, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1028, r_ui=None, est=3.805238437301078, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1029, r_ui=None, est=4.79417263342847, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1030, r_ui=None, est=3.8541287678083784, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1031, r_ui=None, est=3.8524036317199153, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1032, r_ui=None, est=3.8014141978773557, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1033, r_ui=None, est=3.7538197582372717, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1034, r_ui=None, est=3.852735941834799, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1035, r_ui=None, est=4.2604891149389115, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1036, r_ui=None, est=3.989671336224513, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1037, r_ui=None, est=3.667284931583856, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1038, r_ui=None, est=3.95797831948322, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1039, r_ui=None, est=3.302185936779943, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1040, r_ui=None, est=4.1125856916683095, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1041, r_ui=None, est=4.448618734854528, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1042, r_ui=None, est=3.653014647039548, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1043, r_ui=None, est=3.928118208537887, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1044, r_ui=None, est=3.7640416216303905, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1045, r_ui=None, est=3.8512857003756094, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1046, r_ui=None, est=3.9920498398177804, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1047, r_ui=None, est=4.527529303020469, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1048, r_ui=None, est=4.04893126424099, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1049, r_ui=None, est=4.1745985226492355, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1050, r_ui=None, est=3.856227585440518, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1051, r_ui=None, est=4.046708813464076, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1052, r_ui=None, est=3.877671307872041, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1053, r_ui=None, est=4.036878002824524, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1054, r_ui=None, est=3.591890420717153, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1055, r_ui=None, est=3.994705283487424, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1056, r_ui=None, est=3.950247482059931, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1057, r_ui=None, est=3.542437776439517, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1058, r_ui=None, est=4.1009418562653535, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1059, r_ui=None, est=3.8392139694696716, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1060, r_ui=None, est=4.173470496712455, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1061, r_ui=None, est=4.108820395130808, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1062, r_ui=None, est=3.570953334962774, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1063, r_ui=None, est=3.790242005219754, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1064, r_ui=None, est=3.820760565918716, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1065, r_ui=None, est=4.648023045714419, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1066, r_ui=None, est=3.9212866547488603, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1067, r_ui=None, est=3.7762489864432296, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1068, r_ui=None, est=4.118351938137385, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1069, r_ui=None, est=4.246625181529651, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1070, r_ui=None, est=4.046691245654518, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1071, r_ui=None, est=4.118023091396521, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1072, r_ui=None, est=3.672531419238011, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1073, r_ui=None, est=3.6867023843406628, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1074, r_ui=None, est=3.92705917813751, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1075, r_ui=None, est=3.7598040032211086, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1076, r_ui=None, est=3.584935692882877, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1077, r_ui=None, est=4.126609668454618, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1078, r_ui=None, est=3.9084829273216606, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1079, r_ui=None, est=3.2290853460589584, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1080, r_ui=None, est=3.9813726853404323, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1081, r_ui=None, est=4.240567196855188, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1082, r_ui=None, est=3.7836410726694787, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1083, r_ui=None, est=3.6828631745861626, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1084, r_ui=None, est=3.7248403736834814, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1085, r_ui=None, est=3.385932846616361, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1086, r_ui=None, est=3.9658669265208477, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1087, r_ui=None, est=4.13759106900104, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1088, r_ui=None, est=4.122348373783357, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1089, r_ui=None, est=4.2631318321824985, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1090, r_ui=None, est=3.7094645563707886, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1091, r_ui=None, est=3.9834631262227513, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1092, r_ui=None, est=4.07632005236912, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1093, r_ui=None, est=3.6341488551358565, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1094, r_ui=None, est=4.04711775975432, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1095, r_ui=None, est=3.75109095346893, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1096, r_ui=None, est=4.106447473737551, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1097, r_ui=None, est=3.7146996088490742, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1098, r_ui=None, est=3.9919711617268705, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1100, r_ui=None, est=3.972826774051282, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1101, r_ui=None, est=3.8478801517519696, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1102, r_ui=None, est=4.0121554167221865, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1103, r_ui=None, est=3.9265471842612096, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1104, r_ui=None, est=3.1580111199946237, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1105, r_ui=None, est=3.8529067250015134, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1106, r_ui=None, est=4.254953062833306, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1107, r_ui=None, est=3.6124368517696634, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1108, r_ui=None, est=4.284919448045577, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1109, r_ui=None, est=3.7344992255038996, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1110, r_ui=None, est=4.168918693660306, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1111, r_ui=None, est=2.9901797283138, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1112, r_ui=None, est=4.212741551242656, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1113, r_ui=None, est=3.776670236483154, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1114, r_ui=None, est=4.202482521743229, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1115, r_ui=None, est=3.6518972960779688, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1116, r_ui=None, est=3.973695478106759, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1117, r_ui=None, est=3.727489560433083, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1118, r_ui=None, est=3.4495651370807816, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1119, r_ui=None, est=4.180603705900916, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1120, r_ui=None, est=4.152450346781385, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1121, r_ui=None, est=3.9481258639871544, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1122, r_ui=None, est=3.6773127272860853, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1123, r_ui=None, est=3.766737513603353, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1124, r_ui=None, est=3.654474349419087, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1125, r_ui=None, est=3.439200465727519, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1126, r_ui=None, est=3.7987086674042674, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1127, r_ui=None, est=4.008842356279113, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1128, r_ui=None, est=3.997841498563264, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1129, r_ui=None, est=4.056995726307508, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1130, r_ui=None, est=4.29890404312842, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1132, r_ui=None, est=3.6965192424127467, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1134, r_ui=None, est=4.0324366871673885, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1135, r_ui=None, est=4.0460259993735495, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1136, r_ui=None, est=4.14559386467075, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1137, r_ui=None, est=3.9696370213814323, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1138, r_ui=None, est=3.9260752625823887, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1139, r_ui=None, est=3.604204749930376, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1140, r_ui=None, est=3.695248557828945, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1141, r_ui=None, est=4.165455576226504, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1142, r_ui=None, est=4.3804558610972375, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1143, r_ui=None, est=3.6855563337796977, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1145, r_ui=None, est=3.675148599870489, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1146, r_ui=None, est=4.375731870724692, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1147, r_ui=None, est=3.6053706788102513, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1148, r_ui=None, est=4.310212719159387, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1149, r_ui=None, est=3.558094793380617, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1150, r_ui=None, est=4.072950532306323, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1151, r_ui=None, est=3.9629780300873736, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1152, r_ui=None, est=3.5781890858567333, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1153, r_ui=None, est=4.496802656722787, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1154, r_ui=None, est=4.495299721412206, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1156, r_ui=None, est=3.9386191659156298, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1157, r_ui=None, est=3.80709487065487, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1158, r_ui=None, est=4.4008907840315015, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1159, r_ui=None, est=3.5987498323293563, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1160, r_ui=None, est=3.765578495689649, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1161, r_ui=None, est=4.065099702554451, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1162, r_ui=None, est=3.3955838083079253, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1163, r_ui=None, est=3.915624460162136, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1164, r_ui=None, est=3.947279455323038, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1165, r_ui=None, est=4.046890991475325, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1166, r_ui=None, est=4.117864454930726, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1168, r_ui=None, est=3.9234041479902326, details={'was_impossible': False}),
#  Prediction(uid=18313, iid=1169, r_ui=None, est=4.1150812583740075, details={'was_impossible': False}),
#  ...]

# %%
top_n = get_top_n(pred, n=10)
top_n
# Out:
# defaultdict(list,
#             {18313: [(3628, 5),
#               (1308, 4.987570198234232),
#               (8663, 4.967533897974668),
#               (6920, 4.959674680596504),
#               (6361, 4.952630333298262),
#               (3395, 4.943302568163949),
#               (3736, 4.940580395432595),
#               (4229, 4.904086657022224),
#               (9076, 4.888844824005519),
#               (7264, 4.8796943597651055)]})

# %%
# Predecimos el TOP-10 de recomendaciones para el usuario 18313

for uid, user_ratings in top_n.items():
    print([books_metadata.loc[books_metadata.id==iid,'original_title'].values[0] for (iid, _) in user_ratings])

#En el TOP 10 de libros recomendados para nuestro usuario de prueba, vemos libros de ciencia ficción, religión y misterios,
#lo cual guarda sentido con su gusto con los libros de Dan Brown
# Out:
# ['The Complete Calvin and Hobbes', 'A Court of Mist and Fury', 'Locke & Key, Vol. 6: Alpha & Omega', 'The Indispensable Calvin and Hobbes: A Calvin and Hobbes Treasury', "There's Treasure Everywhere: A Calvin and Hobbes Collection", 'The Sandman: The Kindly Ones', 'Harry Potter Page to Screen: The Complete Filmmaking Journey', 'The Lord of the Rings: Weapons and Warfare', 'Preach My Gospel (A Guide to Missionary Service)', 'Master of the Senate']

# %% [markdown]
# ### Comparamos el desempeño de varios algoritmos

# %%
ratings_data_f=ratings_data.sample(n=100000)

# %%
#CUIDADO! Mejor utilizar el método train_test_split de SK Learn, y luego convertir el conjunto de datos resultante al objeto Dataset
train, test = skl_train_test_split(ratings_data_f, test_size=0.20,random_state=100)
reader = Reader(rating_scale=(1, 5))
data_train = Dataset.load_from_df(train, reader)

algo_svd = SVD()
algo_knn = KNNBasic()
algo_random=NormalPredictor()
algo_baseline=BaselineOnly()
algo_nmf=NMF()

# %%
cv_random=cross_validate(algo_random, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)

# %%
cv_baseline=cross_validate(algo_baseline, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_svd=cross_validate(algo_svd, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_knn=cross_validate(algo_knn, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
cv_nmf=cross_validate(algo_nmf, data_train, measures=['RMSE'],cv=4, verbose=False, n_jobs=-1)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Computing the msd similarity matrix...
# Computing the msd similarity matrix...
# Computing the msd similarity matrix...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.

# %%
res=[]
res.append(round(cv_random['test_rmse'].mean(),3))
res.append(round(cv_baseline['test_rmse'].mean(),3))
res.append(round(cv_svd['test_rmse'].mean(),3))
res.append(round(cv_knn['test_rmse'].mean(),3))
res.append(round(cv_nmf['test_rmse'].mean(),3))

res_df=pd.DataFrame(pd.concat([pd.Series(['Random','Baseline','SVD','KNN','NMF']),pd.Series(res)],axis=1))
res_df.columns=['Algoritmo','RMSE CV']
res_df
# Out:
#   Algoritmo  RMSE CV
# 0    Random    1.322
# 1  Baseline    0.934
# 2       SVD    0.935
# 3       KNN    0.992
# 4       NMF    1.118

# %% [markdown]
# Los mejores algoritmos parecen ser el baseline y el SVD.
#
# Ver tiempos de ajuste y rendimiento esperado en https://surpriselib.com/

# %% [markdown]
# ### Métricas específicas de los sistemas de recomendación

# %% [markdown]
# <img src="metricas.png" align="center" width="60%"/>

# %% [markdown]
# - Un elemento se considera **relevante** si su puntuación es superior a un umbral determinado (por ej, mayor o igual a 4). En otras palabras, binarizamos el puntaje para convertir un problema de regresión en uno de clasificacción.
# <br>
#
# - Un elemento se considera **recomendado** si su puntuación estimada es superior al umbral y se encuentra entre las k mejores puntuaciones estimadas.
#
# Tener en cuenta que en los casos extremos en los que se produce una división por cero, los valores Precision@k y Recall@k no están definidos. Por convención, fijamos sus valores en 0 en estos casos.

# %%
from collections import defaultdict

from surprise import Dataset, SVD
from surprise.model_selection import KFold


def precision_recall_at_k(predictions, k=10, threshold=3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(
            ((true_r >= threshold) and (est >= threshold))
            for (est, true_r) in user_ratings[:k]
        )

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

# %%
kf = KFold(n_splits=4)
# algo = SVD()
precision=[]
recall=[]
for trainset, testset in kf.split(data):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=10, threshold=4)

    # Precision and recall can then be averaged over all users
    precision.append(sum(prec for prec in precisions.values()) / len(precisions))
    recall.append(sum(rec for rec in recalls.values()) / len(recalls))

# %%
len(predictions)
# Out:
# 245439

# %%
len(precision)

# %%
len(recall)

# %%
#Top 5
# print(f'Precision media: {np.array(precision).mean()}')
# print(f'Recall medio: {np.array(recall).mean()}')

# Precision media: 0.49
# Recall medio: 0.34

# %%
#Top 10
print(f'Precision media: {np.array(precision).mean()}')
print(f'Recall medio: {np.array(recall).mean()}')

# Precision media: 0.49
# Recall medio: 0.37
# Out:
# Precision media: 0.4858455931008703
# Recall medio: 0.3696506802942668

# %% [markdown]
# Esto significa que, en promedio, el 48% del top 10 de recomendaciones hechas para cada usuario son relevantes (con un puntaje estimado mayor o igual a 4), mientras que de todos los libros relevantes, el 37% aparecieron en el top 10.
#
# --------
#
# Podríamos aumentar k, lo que resultaría en **mayor recall a costa de una menor precision**. Esto es equivalente a utilizar un punto de corte menor (= menos exigentes) en un modelo convencional de ML.

# %% [markdown]
# # PRÁCTICA
#
# Construir dos sistemas de recomendación:
# - uno basado en contenidos a partir de la columna "overview" (argumento de la película). Generar recomendaciones de películas similar a Toy Story.
# - un modelo basado en filtros colaborativos a partir de los ratings. Generar 10 recomendaciones para un fanático de Star Wars.
#
# Además de lo visto en clase, puede ayudarse a partir de lo que aparece acá:
# https://www.datacamp.com/tutorial/recommender-systems-python
#
# El dataset completo está acá: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/data
#
# TAREA para el hogar: construir una función para medir precision@k y recall@k a partir del listado de recomendaciones del SR basado en contenidos.

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
ratings_metadata = pd.read_csv('./data/movies/ratings_small.csv', low_memory=False)
movies_metadata = pd.read_csv('./data/movies/movies_metadata.csv', low_memory=False)

print(ratings_metadata.shape)
ratings_metadata.head()
# Out:
# (100004, 4)
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
print(movies_metadata.shape)
movies_metadata.head()
# Out:
# (45466, 24)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
links = pd.read_csv('./data/movies/links.csv', low_memory=False)
links
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
links.dtypes
# Out:
# movieId      int64
# imdbId       int64
# tmdbId     float64
# dtype: object

# %%
print(movies_metadata.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
import difflib
import random

def get_book_id(book_title, metadata):
    
    existing_titles = list(metadata['title'].values)
    closest_titles = difflib.get_close_matches(book_title, existing_titles)
    book_id = metadata[metadata['title'] == closest_titles[0]]['id'].values[0]
    return book_id

def get_book_info(book_id, metadata):
    
    book_info = metadata[metadata['id'] == book_id][['id', 'imdb_id', 
                                                    'production_companies', 'title', 'original_title']]
    return book_info.to_dict(orient='records')

def predict_review(user_id, book_title, model, metadata):
    
    book_id = get_book_id(book_title, metadata)
    review_prediction = model.predict(uid=user_id, iid=book_id)
    return review_prediction.est

def generate_recommendation(user_id, model, metadata, thresh=4):
    
    book_titles = list(metadata['title'].values)
    random.shuffle(book_titles)
    
    for book_title in book_titles:
        rating = predict_review(user_id, book_title, model, metadata)
        if rating >= thresh:
            book_id = get_book_id(book_title, metadata)
            return get_book_info(book_id, metadata)

# %%
user_id=18313
generate_recommendation(user_id, svd, movies_metadata)

# reader = Reader(rating_scale=(1, 5))
# data = Dataset.load_from_df(ratings_data[['user_id', 'book_id', 'rating']], reader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 user_id=18313
# ----> 2 generate_recommendation(user_id, svd, movies_metadata)
#
# Cell In[79], line 29, in generate_recommendation(user_id, model, metadata, thresh)
#      26 random.shuffle(book_titles)
#      28 for book_title in book_titles:
# ---> 29     rating = predict_review(user_id, book_title, model, metadata)
#      30     if rating >= thresh:
#      31         book_id = get_book_id(book_title, metadata)
#
# Cell In[79], line 19, in predict_review(user_id, book_title, model, metadata)
#      17 def predict_review(user_id, book_title, model, metadata):
# ---> 19     book_id = get_book_id(book_title, metadata)
#      20     review_prediction = model.predict(uid=user_id, iid=book_id)
#      21     return review_prediction.est
#
# Cell In[79], line 7, in get_book_id(book_title, metadata)
#       4 def get_book_id(book_title, metadata):
#       6     existing_titles = list(metadata['title'].values)
# ----> 7     closest_titles = difflib.get_close_matches(book_title, existing_titles)
#       8     book_id = metadata[metadata['title'] == closest_titles[0]]['id'].values[0]
#       9     return book_id
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/difflib.py:726, in get_close_matches(word, possibilities, n, cutoff)
#     724 for x in possibilities:
#     725     s.set_seq1(x)
# --> 726     if s.real_quick_ratio() >= cutoff and \
#     727        s.quick_ratio() >= cutoff and \
#     728        s.ratio() >= cutoff:
#     729         result.append((s.ratio(), x))
#     731 # Move the best scorers to head of list
#
# File ~/anaconda3/envs/itba_apa_env/lib/python3.8/difflib.py:683, in SequenceMatcher.real_quick_ratio(self)
#     676 def real_quick_ratio(self):
#     677     """Return an upper bound on ratio() very quickly.
#     678
#     679     This isn't defined beyond that it is an upper bound on .ratio(), and
#     680     is faster to compute than either .ratio() or .quick_ratio().
#     681     """
# --> 683     la, lb = len(self.a), len(self.b)
#     684     # can't have more matches than the number of elements in the
#     685     # shorter sequence
#     686     return _calculate_ratio(min(la, lb), la + lb)
#
# TypeError: object of type 'float' has no len()

# %%
get_book_id()

# %% [markdown]
# ## BIBLIOGRAFÍA
#
# - https://towardsdatascience.com/how-you-can-build-simple-recommender-systems-with-surprise-b0d32a8e4802
# - https://surprise.readthedocs.io/
# - https://medium.com/mlearning-ai/basic-content-based-recommendation-system-with-python-code-be920b412067
# - https://medium.com/analytics-vidhya/content-based-recommender-systems-in-python-2b330e01eb80
# - https://towardsdatascience.com/hands-on-content-based-recommender-system-using-python-1d643bf314e4
#
# LightFM
# - https://towardsdatascience.com/solving-business-usecases-by-recommender-system-using-lightfm-4ba7b3ac8e62
